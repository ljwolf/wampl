# %%
import wes
# %matplotlib inline

# %%
wes.available(show=True)
# Out:
# (<Figure size 864x864 with 18 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc9c32240f0>,
# ...
#        dtype=object))

# %%
wes.plot_palettes('Rushmore1', 'Moonrise3')
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fc9c08f2da0>,
# ...
#        dtype=object))

# %%
wes.plot_palettes('BottleRocket2')
# Out:
# (<Figure size 432x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fc9c067e080>)

# %%
try:
    import seaborn as sns
except:
    pass
import numpy as np
import matplotlib.pyplot as plt
wes.set_palette('Zissou1')

# %%
for i in range(10):
    plt.plot(range(100), np.random.normal(i, 1, 100))

# %%
wes.set_palette('GrandBudapest1')
for i in range(10):
    plt.plot(range(100), np.random.normal(i, 1, 100))
