# %%
import wes
# %matplotlib inline

# %%
wes.available(show=True)

# %%
wes.plot_palettes('Rushmore', 'Moonrise3')

# %%
wes.plot_palettes('BottleRocket2')

# %%
try:
    import seaborn as sns
except:
    pass
import numpy as np
import matplotlib.pyplot as plt
wes.set_palette('Zissou')

# %%
for i in range(10):
    plt.plot(range(100), np.random.normal(i, 1, 100))

# %%
wes.set_palette('GrandBudapest')
for i in range(10):
    plt.plot(range(100), np.random.normal(i, 1, 100))
